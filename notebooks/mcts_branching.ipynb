# %%
# 04_mcts_branching.ipynb
# ── Cell 1: Imports and load data ──────────────────────────────────────────────
import sys
sys.path.append("..")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from pathlib import Path
from dataclasses import dataclass, field
from typing import Optional
import json, copy

PROCESSED_DIR  = Path("../data_store/processed")
SYNTHETIC_DIR  = Path("../data_store/synthetic")

df = pd.read_csv(
    PROCESSED_DIR / "XAUUSD_5m_features.csv",
    index_col="datetime", parse_dates=True
)

# Load persona config
with open("../config/persona_config.json") as f:
    persona_cfg = json.load(f)

print(f"Loaded: {len(df):,} rows")
print("\nCell 1 passed ✓")

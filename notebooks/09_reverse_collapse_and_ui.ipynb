# %%
import sys
from pathlib import Path

if Path('/home/rocm-user/jupyter/nexus').exists():
    ROOT = Path('/home/rocm-user/jupyter/nexus')
else:
    ROOT = Path(r'C:/PersonalDrive/Programming/AiStudio/nexus-trader')

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print({'root': str(ROOT)})

# %%
from config.project_config import FINAL_DASHBOARD_HTML_PATH, PROBABILITY_CONE_HTML_PATH, PERSONA_BREAKDOWN_HTML_PATH
print({'dashboard': str(FINAL_DASHBOARD_HTML_PATH), 'cone': str(PROBABILITY_CONE_HTML_PATH), 'persona': str(PERSONA_BREAKDOWN_HTML_PATH)})

# %%
from pathlib import Path
for path in [FINAL_DASHBOARD_HTML_PATH, PROBABILITY_CONE_HTML_PATH, PERSONA_BREAKDOWN_HTML_PATH]:
    print(path, path.exists())
